# %% [markdown]
# # Testes
# ### Requisição e limpeza dos dados

# %%
from pymongo import MongoClient
import pandas as pd
import requests
import json

# %%
def getToken():
    
    url = "https://accounts.spotify.com/api/token"

    payload = "grant_type=client_credentials&undefined="
    headers = {
        'Content-Type': "application/x-www-form-urlencoded",
        'Authorization': "Basic NmRhY2QwYTRhMTE3NDVkNTg2ODY1MTc4MWYzOTBlYjk6MmUwMDY3OWJkY2ZjNDhjOGEwYWQ4Y2M2YWMxYTNiMWY=",
        'cache-control': "no-cache",
        'Postman-Token': "26d5613d-6954-4c55-b39a-b9387316f347"
        }

    response = requests.request("POST", url, data=payload, headers=headers)

    fileJson = json.loads(response.text)

    return fileJson['access_token']

# %%
'''
    Conecto ao mongo localmente, e acesso o banco 'teste_tcc'
    Então, retorno todas as playlists encontradas no documento 'top50'
'''
conect = MongoClient('localhost', 27017)
mongo = conect['teste_tcc']
cursor = mongo['top50'].find()

# %%
'''
    Transformo meu documento mongo em lista, logo após em dataset
'''
df = pd.DataFrame(list(cursor))

# %%
'''
    Verifico o tipo de cada coluna da tabela
'''
df.dtypes
# Out:
# _id              object
# collaborative      bool
# external_urls    object
# href             object
# id               object
# images           object
# name             object
# owner            object
# primary_color    object
# public           object
# snapshot_id      object
# tracks           object
# type             object
# uri              object
# dtype: object

# %%
df.head()
# Out:
#                         _id  collaborative  \
# 0  5c8d1a02e77ddf4f42392921          False
# 1  5c8d1a02e77ddf4f42392922          False
# 2  5c8d1a02e77ddf4f42392923          False
# 3  5c8d1a02e77ddf4f42392924          False
# 4  5c8d1a02e77ddf4f42392925          False
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/playlist...
# 1  {'spotify': 'https://open.spotify.com/playlist...
# 2  {'spotify': 'https://open.spotify.com/playlist...
# 3  {'spotify': 'https://open.spotify.com/playlist...
# 4  {'spotify': 'https://open.spotify.com/playlist...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/playlists/37i9dQZF1...  37i9dQZF1DXcBWIGoYBM5M
# 1  https://api.spotify.com/v1/playlists/6KOrRaDpT...  6KOrRaDpTadIb8kEm4WEeb
# 2  https://api.spotify.com/v1/playlists/3rZxxXCtm...  3rZxxXCtmadQUjaUe9VGIw
# ...

# %%
df.columns
# Out:
# Index(['_id', 'collaborative', 'external_urls', 'href', 'id', 'images', 'name',
#        'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type',
#        'uri'],
#       dtype='object')

# %%
df = df.drop(columns=['_id', 'collaborative', 'images', 'owner',
                      'primary_color', 'public', 'snapshot_id', 
                      'type','uri'])
df = df.rename(columns={
    "external_urls": "link_spotify",
    "href": "href_playlist",
    "id": "id_playlist",
    "name": "nome",
    "tracks": "href_faixas"
})


df.head()
# Out:
#                                         link_spotify  \
# 0  {'spotify': 'https://open.spotify.com/playlist...
# 1  {'spotify': 'https://open.spotify.com/playlist...
# 2  {'spotify': 'https://open.spotify.com/playlist...
# 3  {'spotify': 'https://open.spotify.com/playlist...
# 4  {'spotify': 'https://open.spotify.com/playlist...
#
#                                        href_playlist             id_playlist  \
# 0  https://api.spotify.com/v1/playlists/37i9dQZF1...  37i9dQZF1DXcBWIGoYBM5M
# 1  https://api.spotify.com/v1/playlists/6KOrRaDpT...  6KOrRaDpTadIb8kEm4WEeb
# 2  https://api.spotify.com/v1/playlists/3rZxxXCtm...  3rZxxXCtmadQUjaUe9VGIw
# 3  https://api.spotify.com/v1/playlists/1QM1qz09Z...  1QM1qz09ZzsAPiXphF1l4S
# 4  https://api.spotify.com/v1/playlists/4nNVfQ9eW...  4nNVfQ9eWidZXkBKZN5li4
#
#                                     nome  \
# 0                       Today's Top Hits
# 1  Top 50 Nederland - Nederlandse Top 50
# 2      TOP 50 ARGENTINA 🇦🇷 TOP 50 ÉXITOS
# ...

# %%
df['num_faixas'] = df['href_faixas']

# %%
df.head()
# Out:
#                                         link_spotify  \
# 0  {'spotify': 'https://open.spotify.com/playlist...
# 1  {'spotify': 'https://open.spotify.com/playlist...
# 2  {'spotify': 'https://open.spotify.com/playlist...
# 3  {'spotify': 'https://open.spotify.com/playlist...
# 4  {'spotify': 'https://open.spotify.com/playlist...
#
#                                        href_playlist             id_playlist  \
# 0  https://api.spotify.com/v1/playlists/37i9dQZF1...  37i9dQZF1DXcBWIGoYBM5M
# 1  https://api.spotify.com/v1/playlists/6KOrRaDpT...  6KOrRaDpTadIb8kEm4WEeb
# 2  https://api.spotify.com/v1/playlists/3rZxxXCtm...  3rZxxXCtmadQUjaUe9VGIw
# 3  https://api.spotify.com/v1/playlists/1QM1qz09Z...  1QM1qz09ZzsAPiXphF1l4S
# 4  https://api.spotify.com/v1/playlists/4nNVfQ9eW...  4nNVfQ9eWidZXkBKZN5li4
#
#                                     nome  \
# 0                       Today's Top Hits
# 1  Top 50 Nederland - Nederlandse Top 50
# 2      TOP 50 ARGENTINA 🇦🇷 TOP 50 ÉXITOS
# ...

# %%
for index, link in enumerate(df['link_spotify'], start=0):
    df['link_spotify'][index] = link['spotify']
    
for index, link in enumerate(df['href_faixas'], start=0):
    df['href_faixas'][index] = link['href']
    df['num_faixas'][index] = link['total']

df.head()
# Out:
#                                         link_spotify  \
# 0  https://open.spotify.com/playlist/37i9dQZF1DXc...
# 1  https://open.spotify.com/playlist/6KOrRaDpTadI...
# 2  https://open.spotify.com/playlist/3rZxxXCtmadQ...
# 3  https://open.spotify.com/playlist/1QM1qz09ZzsA...
# 4  https://open.spotify.com/playlist/4nNVfQ9eWidZ...
#
#                                        href_playlist             id_playlist  \
# 0  https://api.spotify.com/v1/playlists/37i9dQZF1...  37i9dQZF1DXcBWIGoYBM5M
# 1  https://api.spotify.com/v1/playlists/6KOrRaDpT...  6KOrRaDpTadIb8kEm4WEeb
# 2  https://api.spotify.com/v1/playlists/3rZxxXCtm...  3rZxxXCtmadQUjaUe9VGIw
# 3  https://api.spotify.com/v1/playlists/1QM1qz09Z...  1QM1qz09ZzsAPiXphF1l4S
# 4  https://api.spotify.com/v1/playlists/4nNVfQ9eW...  4nNVfQ9eWidZXkBKZN5li4
#
#                                     nome  \
# 0                       Today's Top Hits
# 1  Top 50 Nederland - Nederlandse Top 50
# 2      TOP 50 ARGENTINA 🇦🇷 TOP 50 ÉXITOS
# ...

# %%
url = df.href_faixas[0]

headers = {
    'Authorization': "Bearer " + getToken()
}

response = requests.request("GET", url, headers=headers)
fileJson = json.loads(response.text)

# %%
df_faixas_itens = pd.DataFrame(list(fileJson['items']))

# %%
df_faixas_itens.head()
# Out:
#                added_at                                           added_by  \
# 0  2019-03-18T11:52:39Z  {'external_urls': {'spotify': 'https://open.sp...
# 1  2019-03-18T11:52:39Z  {'external_urls': {'spotify': 'https://open.sp...
# 2  2019-03-18T11:52:39Z  {'external_urls': {'spotify': 'https://open.sp...
# 3  2019-03-18T11:52:39Z  {'external_urls': {'spotify': 'https://open.sp...
# 4  2019-03-18T11:52:39Z  {'external_urls': {'spotify': 'https://open.sp...
#
#    is_local primary_color                                              track  \
# 0     False       #02c9ea  {'album': {'album_type': 'single', 'artists': ...
# 1     False       #adc1da  {'album': {'album_type': 'single', 'artists': ...
# 2     False       #c98d6f  {'album': {'album_type': 'single', 'artists': ...
# 3     False       #c73740  {'album': {'album_type': 'album', 'artists': [...
# 4     False       #ea701c  {'album': {'album_type': 'single', 'artists': ...
#
#   video_thumbnail
# 0   {'url': None}
# ...

# %%
df_faixas = pd.DataFrame(list(df_faixas_itens.track))
df_faixas.head()
# Out:
#                                                album  \
# 0  {'album_type': 'single', 'artists': [{'externa...
# 1  {'album_type': 'single', 'artists': [{'externa...
# 2  {'album_type': 'single', 'artists': [{'externa...
# 3  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'single', 'artists': [{'externa...
#
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# 1  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# 2  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# ...

# %%
df_faixas.loc[0, ['album']]
# Out:
# album    {'album_type': 'single', 'artists': [{'externa...
# Name: 0, dtype: object

# %%
for index, album in enumerate(df_faixas.album, start=0):
    df_faixas.album[index] = album['name']

df_faixas.head()
# Out:
# /home/adriano/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                album  \
# 0                                       Here With Me
# 1                                             Sucker
# 2  I Can’t Get Enough (benny blanco, Selena Gomez...
# 3                             Ivy To Roses (Mixtape)
# 4                                             My Bad
#
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
# ...

# %%
for index, artists in enumerate(df_faixas.artists, start=0):
    df_faixas.artists[index] = artists[0]['name']

df_faixas.head()
# Out:
# /home/adriano/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                album         artists  \
# 0                                       Here With Me      Marshmello
# 1                                             Sucker  Jonas Brothers
# 2  I Can’t Get Enough (benny blanco, Selena Gomez...    benny blanco
# 3                             Ivy To Roses (Mixtape)           Mabel
# 4                                             My Bad          Khalid
#
#                                    available_markets  disc_number  \
# 0  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# 1  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# ...

# %%
df_faixas = df_faixas.drop(columns=['available_markets', 'disc_number',
       'episode', 'explicit', 'external_ids','is_local', 'preview_url', 'track',
       'track_number', 'type', 'uri'])
df_faixas.head()
# Out:
#                                                album         artists  \
# 0                                       Here With Me      Marshmello
# 1                                             Sucker  Jonas Brothers
# 2  I Can’t Get Enough (benny blanco, Selena Gomez...    benny blanco
# 3                             Ivy To Roses (Mixtape)           Mabel
# 4                                             My Bad          Khalid
#
#    duration_ms                                      external_urls  \
# 0       156346  {'spotify': 'https://open.spotify.com/track/5i...
# 1       181040  {'spotify': 'https://open.spotify.com/track/4y...
# 2       158027  {'spotify': 'https://open.spotify.com/track/1W...
# 3       178480  {'spotify': 'https://open.spotify.com/track/5W...
# 4       166101  {'spotify': 'https://open.spotify.com/track/1D...
#
#                                                 href                      id  \
# ...

# %%
df_faixas.tail()
# Out:
#                             album         artists  duration_ms  \
# 45                        Secreto        Anuel Aa       258800
# 46         Inner Monologue Part 1  Julia Michaels       173306
# 47                   MIDDLE CHILD         J. Cole       213593
# 48                      Big Plans    Why Don't We       179929
# 49  I Don’t Even Know You Anymore          Netsky       167600
#
#                                         external_urls  \
# 45  {'spotify': 'https://open.spotify.com/track/5W...
# 46  {'spotify': 'https://open.spotify.com/track/5W...
# 47  {'spotify': 'https://open.spotify.com/track/2J...
# 48  {'spotify': 'https://open.spotify.com/track/6Y...
# 49  {'spotify': 'https://open.spotify.com/track/5p...
#
#                                                  href                      id  \
# 45  https://api.spotify.com/v1/tracks/5W83ErFkO3aK...  5W83ErFkO3aKAIS1WMi6u0
# 46  https://api.spotify.com/v1/tracks/5WtfUKzXircv...  5WtfUKzXircvW8l5aaVZWT
# ...

# %%
payload = ""
headers = {
    'Authorization': "Bearer " + getToken()
}

keys = [
    'danceability',
    'energy',
    'loudness', 
    'speechiness',
    'acousticness',
    'instrumentalness',
    'liveness',
    'valence',
    'tempo'
]

# Cria um dicionário para inserir as chaves que desejo
infor = {}
infor = infor.fromkeys(keys)

for key in infor.keys():
    infor[key] = []


url = "https://api.spotify.com/v1/audio-features/" + df_faixas['id'][1]
response = requests.request("GET", url, data=payload, headers=headers)
track_info = json.loads(response.text)
print(track_info)

for index in range(0, len(df_faixas.index)):
    id = df_faixas['id'][index]
    url = "https://api.spotify.com/v1/audio-features/" + id
    response = requests.request("GET", url, data=payload, headers=headers)
    track_info = json.loads(response.text)
    for key in infor.keys():
        infor[key].append(track_info[key])
# Out:
# {'danceability': 0.842, 'energy': 0.734, 'key': 1, 'loudness': -5.065, 'mode': 0, 'speechiness': 0.0588, 'acousticness': 0.0427, 'instrumentalness': 0, 'liveness': 0.106, 'valence': 0.952, 'tempo': 137.958, 'type': 'audio_features', 'id': '4y3OI86AEP6PQoDE6olYhO', 'uri': 'spotify:track:4y3OI86AEP6PQoDE6olYhO', 'track_href': 'https://api.spotify.com/v1/tracks/4y3OI86AEP6PQoDE6olYhO', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4y3OI86AEP6PQoDE6olYhO', 'duration_ms': 181040, 'time_signature': 4}

# %%
for key in infor.keys():
    df_faixas[key] = pd.Series(infor[key])
    
df_faixas.head()
# Out:
#                                                album         artists  \
# 0                                       Here With Me      Marshmello
# 1                                             Sucker  Jonas Brothers
# 2  I Can’t Get Enough (benny blanco, Selena Gomez...    benny blanco
# 3                             Ivy To Roses (Mixtape)           Mabel
# 4                                             My Bad          Khalid
#
#    duration_ms                                      external_urls  \
# 0       156346  {'spotify': 'https://open.spotify.com/track/5i...
# 1       181040  {'spotify': 'https://open.spotify.com/track/4y...
# 2       158027  {'spotify': 'https://open.spotify.com/track/1W...
# 3       178480  {'spotify': 'https://open.spotify.com/track/5W...
# 4       166101  {'spotify': 'https://open.spotify.com/track/1D...
#
#                                                 href                      id  \
# ...

# %%
len(df_faixas.index)
# Out:
# 50
